# %%
from bs4 import BeautifulSoup
import selenium.webdriver as webdriver
import urllib.parse
from urllib.request import Request, urlopen
from time import sleep
import pandas as pd

# %%
search= input("검색어를 입력하세요: ")
searching= str(search)
search= urllib.parse.quote(search)
url= 'https://www.instagram.com/explore/tags/'+str(search)+'/'
driver= webdriver.Chrome('c:/chromedriver.exe')
# Out:
# 검색어를 입력하세요: 환경

# %%
driver.get(url)
sleep(3)

SCROLL_PAUSE_TIME= 1.2

# %%
reallink= []

while True:
    pageString= driver.page_source
    bs= BeautifulSoup(pageString, "lxml")
    
    for link1 in bs.find_all(name= "div",attrs= {'class':'Nnq7C weEfm'}):
        title = link1.select('a')[0]
        real= title.attrs['href']
        reallink.append(real)
        title= link1.select('a')[1]
        real= title.attrs['href']
        reallink.append(real)
    
    last_height= driver.execute_script('return document.body.scrollHeight')
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    sleep(SCROLL_PAUSE_TIME)
    new_height= driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        sleep(SCROLL_PAUSE_TIME)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        
        else:
            last_height = new_height
            continue

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
import configparser
import glob

config = configparser.ConfigParser()

def to_csv(data):
    
    pathlink = "./"
    
    if not os.path.isdir(pathlink):
        os.mkdir(pathlink)
        
    present_date= str(datetime.utcnow() + timedelta(hours = 9))[:10]
    
    if len(glob.glob(pathlink + "/" + present_date + ".csv")) ==1:
        cnt= len(pd.read_csv(pathlink + "/" + present_date + ".csv", index_col=0).index)
        time_pd = pd.DataFrame(data, index=[cnt])
        time_pd.to_csv(pathlink + "/" + present_date + ".csv", mode='a', header= False, encoding='utf-8-sig')
    
    else:
        cnt= 0
        time_pd = pd.DataFrame(data,index=[cnt])
        time_pd.to_csv(pathlink + "/" + present_date + ".csv", mode='a', encoding='utf-8-sig')

# %%
import pandas_csv

hashtags2= []

reallinknum= len(reallink)
print("총" + str(reallinknum)+"개의 데이터.")
try:
    for i in range(0, reallinknum):
        hashtags2.append([])
        req= 'https://www.instagram.com' + reallink[i]
        driver.get(req)
        webpage= driver.page_source
        soup= BeautifulSoup(webpage, "html.parser")
        
        soup1= str(soup.find_all(attrs={'class':'e1e1d'}))
        user_id= soup1.split('href="/')[1]
        
        subValue = 'span'
        if (soup1=="[]"):
            likes = '0'
        elif (soup1.find(subValue)== -1):
            likes= soup1.split('좋아요')[1].split('개')[0]
        elif (soup1.find(subValue)!= -1):
            likes= soup1.split('<span>')[1].split('<span>')[0]
            
        soup1 = str(soup.find_all(attrs={'class': 'xil3i'}))
        if (soup1=="[]"):
            hashtags = '해쉬태그없음'
            insert_data = {"search": searching,
                          "user_id": user_id,
                          "좋아요": likes,
                          "hashtags": hashtags}
            pandas_csv.to_csv(insert_data)
        else:
            soup2 = soup1.split(',')
            soup2num = len(soup2)
            for j in range(0, soup2num):
                hashtags = soup2[j].split('#')[1].split('</a>')[0]
                print(hashtags)
                insert_data = {"search": searching,
                              "user_id": user_id,
                              "좋아요": likes,
                              "hashtags": hashtags}
                pandas_csv.to_csv(insert_data)

except:
    print("오류발생" + str(i+1) +"개의 데이터를 저장합니다.")

print("저장성공")
# Out:
# 총12622개의 데이터.
# 오류발생1개의 데이터를 저장합니다.
# 저장성공

# %%
 for i in range(0, reallinknum):
        hashtags2.append([])
        req= 'https://www.instagram.com' + reallink[i]
        driver.get(req)
        webpage= driver.page_source
        soup= BeautifulSoup(webpage, "html.parser")
        
        soup1= str(soup.find_all(attrs={'class':'e1e1d'}))
        user_id= soup1.split('href="/')[1].split('/">')[0]
        
        soup1= str(soup.find_all(attrs={'class': 'Nm9Fw'}))
        subValue = 'span'
            
        soup1 = str(soup.find_all(attrs={'class': 'xil3i'}))
        if (soup1=="[]"):
            hashtags = '해쉬태그없음'
            insert_data = {"search": searching,
                          "user_id": user_id,
                          "hashtags": hashtags}
            pandas_csv.to_csv(insert_data)
        else:
            soup2 = soup1.split(',')
            soup2num = len(soup2)
            for j in range(0, soup2num):
                hashtags = soup2[j].split('#')[1].split('</a>')[0]
                print(hashtags)
                insert_data = {"search": searching,
                              "user_id": user_id,
                              "hashtags": hashtags}
                pandas_csv.to_csv(insert_data)
# Out:
# 스브스뉴스
# 환경보호
# 친환경
# 필환경
# 환경
# 이너보틀
# 제로웨이스트
# 로우웨이스트
# 용기
# 화장품
# 발명
# 발명가
# 개발
# 판교
# 스타트업
# 들꽃
# 캔버스
# 캘리소품
# 러블리페이퍼
# 재능기부
# 폐지로만든캔버스
# 대전캘리그라피
# 캘리그라피
# 붓펜취미반
# 하늘물고기
# 하늘물고기2호점
# 꽃
# 페이퍼캔버스
# 업사이클링
# 친환경
# 폐박스
# 폐지
# 그림선물
# 환경
# 나눔
# 사람
# 사랑
# 스브스뉴스
# 스팸뚜껑
# 스팸
# 환경보호
# 환경
# 친환경
# 친환경제품
# 친환경포장
# 착한소비
# 플라스틱
# 플라스틱줄이기
# 플라스틱제로
# 추석선물
# 추석선물세트
# spam
# cj제일제당
# 스브스뉴스
# 환경보호
# 쓰레기
# 환경
# 자연
# 청소
# 비치클린
# 세이브제주바다
# 제주
# 제주도
# 바다
# 해변
# 클린산행
# 클린하이킹
# 클린하이커스
# 산
# 등산
# 플로깅
# leavegoodtrace
# 플로깅
# repost
# 미소이야기
# 한국환경산업기술원
# 친환경
# 환경
# 친환경라이프
# 친환경스토리
# SNS
# SNS이벤트
# 이벤트
# 퀴즈
# 퀴즈이벤트
# 설문
# 파스쿠찌
# 바닐라라떼
# 동물퀴즈
# 댓글이벤트
# 미소이야기
# 한국환경산업기술원
# 친환경
# 환경
# 친환경라이프
# 친환경스토리
# SNS
# SNS이벤트
# 이벤트
# 퀴즈
# 퀴즈이벤트
# 설문
# 파스쿠찌
# 바닐라라떼
# 동물퀴즈
# 댓글이벤트
# 미소이야기
# 한국환경산업기술원
# 친환경
# 환경
# 친환경라이프
# 친환경스토리
# SNS
# SNS이벤트
# 이벤트
# 퀴즈
# 퀴즈이벤트
# 설문
# 파스쿠찌
# 바닐라라떼
# 동물퀴즈
# 댓글이벤트
# 미소이야기
# 한국환경산업기술원
# 미소이야기
# 강아지😄😄
# 미소이야기
# 강아지
# 참여완료
# 책
# 인간없는세상
# 앨런와이즈먼
# 최재천
# 환경
# 오염
# 지구
# 인간
# 인류
# 멸종
# 미래
# 과학
# 생명
# 생태계
# 세상
# 통찰
# 일상
# 소통
# 공감
# 책스타그램
# 북스타그램
# 독서스타그램
# 책추천
# 서평
# 북리뷰
# 짧은글
# 오마이어스
# 쿨해지구
# ohmyearth
# 온난화
# 지구온난화
# 온실가스
# 환경
# 친환경
# 제로웨이스트
# 영구동토층
# 동토층
# 북극
# 세계산림총회
# 동화
# 어린이
# 인수감염
# 산림청
# 세계산림총회
# 애니매이션
# 동화
# 숲놀이터
# 환경
# 환경교육
# 자연
# 오늘의메뉴
# 고기없는월요일
# 우렁된장찌개
# 다시마솥밥
# 호박잎
# 편스토랑
# 고기없는월요일캠페인
# 지구살리기
# 제로웨이스트
# 환경
# savingtheearth
# 환경보호
# 오늘도잘먹었습니다🙏
# 건강한식단
# 홈쿡
# 집밥스타그램
# 요리스타그램
# 요리레시피공유
# 온더테이블
# 건강요리
# 제철음식
# 집밥
# healthyfoods
# homecooking
# 제15차세계산림총회
# 서포터즈
# 나무
# 산림청
# 세계산림총회
# wfc
# wfc2021
# 알기쉬운산림지식
# 숲의민족
# 우주수
# 세계수
# 장니
# 자작나무
# 카드뉴스
# 숲
# 자연
# 환경
# 경주여행
# ㄴㄴ
# 경주출장
# ㅋㅋㅋ
# 경주
# 지방
# 출장
# 한복
# ❤️
# 좋아요
# 당일치기여행
# 당일치기
# 드라이브
# 김기사
# 근무
# 환경
# 복지
# 개쩜
# 👍
# 휴가
# 휴식
# 힐링
# 에너지
# 충전
# 행복
# 다시
# 화이팅
# 한국
# 부산
# 남자
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-d0bd2b44abcc> in <module>
#       2        hashtags2.append([])
#       3        req= 'https://www.instagram.com' + reallink[i]
# ----> 4        driver.get(req)
#       5        webpage= driver.page_source
#       6        soup= BeautifulSoup(webpage, "html.parser")
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# c:\ProgramData\Anaconda3\envs\py37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
