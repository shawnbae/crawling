# %%
from tika import parser

PDFfileName = '1020137002003A.pdf'

inputpath = PDFfileName

parsed = parser.from_file(PDFfileName,)
parsed["content"]
# Out:
# 2021-04-28 15:46:17,238 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.24/tika-server-1.24.jar to C:\Users\2021090\AppData\Local\Temp\tika-server.jar.
# 2021-04-28 15:48:55,637 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# ...
